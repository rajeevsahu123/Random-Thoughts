# %% [markdown]
# # Keep motivating yourself !!!!

# %%
from IPython.display import YouTubeVideo

# %%
# Don't Ask For Permission To Be Great (Motivational Video - Lisa Nichols)
YouTubeVideo('oNanJKtU5LE')

# %%
# 'Clean Speech' by Taylor Swift
YouTubeVideo('zMu4iA8qIzs')

# %%
# It is okay not to have a plan | Mithila Palkar | TEDxNITSilchar
YouTubeVideo('rmeGVhhbGrM')

# %%
# Don't Take Anything In Your Life For Granted
YouTubeVideo('Wna-8qFy_v0')

# %%
# It's All Within You
YouTubeVideo('WpjHLimZmmQ')
